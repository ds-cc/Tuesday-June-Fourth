# %% [markdown]
# <a href="https://colab.research.google.com/github/nrvanwyck/Tuesday-June-Fourth/blob/master/Krista_Shepard%2C_Aki_Evans%2C_Nathan_Van_Wyck_Student_Expectations_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/nrvanwyck/Tuesday-June-Fourth/master/survey.csv')
df
# Out:
#                 Unnamed: 0  ...            In a classroom I
# 0   Evangelista Torricelli  ...  just listen and take notes
# 1               Pythagoras  ...  just listen and take notes
# 2                  Alhazen  ...  just listen and take notes
# 3             Randy Pausch  ...  just listen and take notes
# 4                  Alhazen  ...                         NaN
# 5          Wilder Penfield  ...  just listen and take notes
# 6         Claudius Ptolemy  ...  just listen and take notes
# 7              Jean Piaget  ...  just listen and take notes
# 8         Claudius Ptolemy  ...  just listen and take notes
# 9           Clyde Tombaugh  ...      ask a lot of questions
# 10        Joseph Priestley  ...      ask a lot of questions
# 11  Evangelista Torricelli  ...      ask a lot of questions
# 12          Beatrix Potter  ...  just listen and take notes
# 13         Wilder Penfield  ...      ask a lot of questions
# 14           Louis Agassiz  ...  just listen and take notes
# ...

# %%
df.describe()
# Out:
#        What is your programming level?  ...  What level are you going to be when you finish Data Science at Lambda School? 😀
# count                        29.000000  ...                                          29.000000
# mean                          3.689655  ...                                           9.689655
# std                           2.253623  ...                                           0.806379
# min                           1.000000  ...                                           6.000000
# 25%                           2.000000  ...                                          10.000000
# 50%                           3.000000  ...                                          10.000000
# 75%                           5.000000  ...                                          10.000000
# max                          10.000000  ...                                          10.000000
#
# [8 rows x 3 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                                                                          object
# What is your programming level?                                                    float64
# What is your math level?                                                           float64
# What level are you going to be when you finish Data Science at Lambda School? 😀    float64
# In a classroom I                                                                    object
# dtype: object

# %%
df.shape
# Out:
# (30, 5)

# %%
df.head()
# Out:
#                Unnamed: 0  ...            In a classroom I
# 0  Evangelista Torricelli  ...  just listen and take notes
# 1              Pythagoras  ...  just listen and take notes
# 2                 Alhazen  ...  just listen and take notes
# 3            Randy Pausch  ...  just listen and take notes
# 4                 Alhazen  ...                         NaN
#
# [5 rows x 5 columns]

# %%
pd.crosstab(df["What is your programming level?"], df["What is your math level?"])
# Out:
# What is your math level?         2.0   3.0   4.0   5.0   ...  7.0   8.0   9.0   10.0
# What is your programming level?                          ...
# 1.0                                 1     1     1     0  ...     2     0     1     0
# 2.0                                 0     1     0     0  ...     0     0     0     0
# 3.0                                 0     3     1     2  ...     0     0     0     0
# 4.0                                 0     0     0     1  ...     1     0     0     0
# 5.0                                 0     0     0     1  ...     0     0     1     0
# 6.0                                 0     0     0     0  ...     0     2     0     0
# 8.0                                 0     0     0     0  ...     0     1     0     0
# 10.0                                0     0     0     0  ...     0     0     0     1
#
# [8 rows x 9 columns]

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## Some findings
#
# - Visually, we saw that almost everyone reported that their level would be 9 or 10 at the end of their Lambda School instruction.
#
# - We also saw that students who reported a higher programming level tended to report a higher math level and vice versa.
